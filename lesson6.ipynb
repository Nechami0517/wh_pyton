# %%
#### 1.1. ייבא פנדה והפנה את החבילה כ-pd + טען את "telecom_churn.csv" והקצה למשתנה df <span style= color:#0033cc>(3 נקודות)</span>\

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('telecom_churn.csv')

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
 Return the column labels/names

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
 Print the df shape (3 points)

# %%
df.shape
# Out:
# (3333, 20)

# %%
2. מהו סך כל שיחות היום לפי מדינה וקידומת?

# %%
df2 = df.groupby(['State','Area code']).count()
df2.count()
df2.agg(["sum"])
# Out:
#      Account length  International plan  Voice mail plan  \
# sum            3333                3333             3333
#
#      Number vmail messages  Total day minutes  Total day calls  \
# sum                   3333               3333             3333
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# sum              3333               3333             3333              3333
#
#      Total night minutes  Total night calls  Total night charge  \
# sum                 3333               3333                3333
#
#      Total intl minutes  Total intl calls  Total intl charge  \
# sum                3333              3333               3333
#
#      Customer service calls  Churn
# sum                    3333   3333

# %%
df2.reset_index(inplace=True)
df2
# Out:
#     State  Area code  Account length  International plan  Voice mail plan  \
# 0      AK        408              14                  14               14
# 1      AK        415              24                  24               24
# 2      AK        510              14                  14               14
# 3      AL        408              25                  25               25
# 4      AL        415              40                  40               40
# ..    ...        ...             ...                 ...              ...
# 148    WV        415              52                  52               52
# 149    WV        510              34                  34               34
# 150    WY        408              17                  17               17
# 151    WY        415              41                  41               41
# 152    WY        510              19                  19               19
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# ...

# %%
3------------

# %%
df2=df['Churn'] = pd.to_numeric(df['Churn'], downcast='integer', errors='coerce')
df2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool

# %%
df.Churn = df.Churn.replace({True: 1, False: 0})
df.Churn
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_15776\2679179061.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Churn = df.Churn.replace({True: 1, False: 0})
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
isChurn = df.Churn.eq(1).sum()/df.Churn.count()
isChurn
# Out:
# np.float64(0.14491449144914492)

# %%
dfChurn = df.loc[df['Churn'] == 1]

# %%
dfChurn['Total day minutes'].sum()
# Out:
# np.float64(99939.5)

# %% [markdown]
# 3.5 What is the maximum length of international calls among loyal users who do not have an international plan? ('International plan' == 'No') (5 points)

# %%
dfloyal = df.loc[df['Churn'] == 0]
dfloyal = dfloyal.loc[df['International plan'] == 'No']

# %%
dfloyal
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
dfloyal['Total intl calls'].max()
# Out:
# np.int64(19)

# %%
dfloyal['Total intl calls'].max()
# Out:
# np.int64(19)

# %%
def top(func,sort,n):
    return df.loc[func].sort_values(sort).head(n)

# %%
top(df.Churn== 1,'Total intl calls',3)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2536    CT             119        408                 No              No
# 2526    NJ              57        510                Yes              No
# 372     CA             151        415                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2536                      0              294.2              100
# 2526                      0              115.0               65
# 372                       0              218.0               57
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2536             50.01              232.5               53             19.76
# 2526             19.55              122.3               96             10.40
# 372              37.06              114.4               88              9.72
#
#       Total night minutes  Total night calls  Total night charge  \
# ...

# %%
top(df.Churn== 0,'Total intl calls',3)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2362    ND             101        415                 No              No
# 2345    FL              98        408                 No              No
# 712     MO             106        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2362                      0              217.7              118
# 2345                      0              288.1              101
# 712                       0              114.4              104
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2362             37.01              231.7              128             19.69
# 2345             48.98              137.9               93             11.72
# 712              19.45               78.3              101              6.66
#
#       Total night minutes  Total night calls  Total night charge  \
# ...

# %%
def top1(df):
    return df.sort_values('Total intl calls', ascending=[False]).head(3)
df1 = df.groupby('International plan').apply(top1)
df1
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_15776\85415939.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df1 = df.groupby('International plan').apply(top1)
#                         State  Account length  Area code International plan  \
# International plan
# No                 22      AZ             130        415                 No
#                    982     ND              84        415                 No
#                    377     ND              79        408                 No
# Yes                3291    MI             119        510                Yes
#                    957     NV             144        415                Yes
# ...

# %%
df['total_charge'] = df[['Total day charge', 'Total eve charge','Total night charge','Total intl charge']].sum(axis=1)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df['Day_charge_pct'] = df['Total day charge']/df['total_charge']
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
pip install matplotlib
import matplotlib.pyplot as plt
# Out:
#   Cell In[105], line 1
#     pip install matplotlib
#         ^
# SyntaxError: invalid syntax
